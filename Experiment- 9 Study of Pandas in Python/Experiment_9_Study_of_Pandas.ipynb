# %% [markdown]
# ## Experiment- 9 EDA- DATE- 18/02/2026
# ## Name : Drishti Heda
# ## PRN : 25070123045
# ## Batch : EnTC A3
# ## Title: Study of Pandas

# %%
# Initialisation of Pandas

import pandas as pd

s = pd.Series([1, 3, 5, 6, 8])
s
# Out:
# 0    1
# 1    3
# 2    5
# 3    6
# 4    8
# dtype: int64

# %%
# Create a Dataframe

data = {
    "Name" : ["Tanmay", "Tannishtha", "Jahnvi", "Jayvee", "Drishti"],
    "Marks" : [95, 100, 93, 85, 89]
}
df = pd.DataFrame(data)
df
# Out:
#          Name  Marks
# 0      Tanmay     95
# 1  Tannishtha    100
# 2      Jahnvi     93
# 3      Jayvee     85
# 4     Drishti     89

# %%
df.head()
# df.tail()
# Out:
#          Name  Marks
# 0      Tanmay     95
# 1  Tannishtha    100
# 2      Jahnvi     93
# 3      Jayvee     85
# 4     Drishti     89

# %%
''' if nothing is mentioned in the bracet then first and last five is printed
for head and tail function. Nut, the number of rows to be printed can be changed'''

df.head(2)
# Out:
#          Name  Marks
# 0      Tanmay     95
# 1  Tannishtha    100

# %%
df.tail(3)
# Out:
#       Name  Marks
# 2   Jahnvi     93
# 3   Jayvee     85
# 4  Drishti     89

# %%
# Find the structure of the dataframe

df.shape
# Out:
# (5, 2)

# %%
# To check the number of columns

df.ndim
# Out:
# 2

# %%
# To check the number of columns

df.ndim
# Out:
# 2

# %%
# Total number of elements = no of columns x no of rows

df.size
# Out:
# 10

# %%
# Display column Names

df.columns
# Out:
# Index(['Name', 'Marks'], dtype='object')

# %%
# Check Data Types of each Column
# object   -   Categorical data
# int64    -   Numerical Data

df.dtypes
# Out:
# Name     object
# Marks     int64
# dtype: object

# %%
# Access Individual Column

df["Name"]
# Out:
# 0        Tanmay
# 1    Tannishtha
# 2        Jahnvi
# 3        Jayvee
# 4       Drishti
# Name: Name, dtype: object

# %%
# Access Individual Column

df["Name"]
# Out:
# 0        Tanmay
# 1    Tannishtha
# 2        Jahnvi
# 3        Jayvee
# 4       Drishti
# Name: Name, dtype: object

# %%
# Access Specific Row

df.loc[3]
# Out:
# Name     Jayvee
# Marks        85
# Name: 3, dtype: object

# %%
# Add a New Column

df["Grade"] = ["First Class", "Distinction", "First Class", "Second Class", "Second Class"]

df
# Out:
#          Name  Marks         Grade
# 0      Tanmay     95   First Class
# 1  Tannishtha    100   Distinction
# 2      Jahnvi     93   First Class
# 3      Jayvee     85  Second Class
# 4     Drishti     89  Second Class

# %%
# Update Data in DataFrame
# Change marks of third student to 97

df.loc[2, "Marks"] = 100
df.loc[2, "Grade"] = "Distinction"
df
# Out:
#          Name  Marks         Grade
# 0      Tanmay     95   First Class
# 1  Tannishtha    100   Distinction
# 2      Jahnvi    100   Distinction
# 3      Jayvee     85  Second Class
# 4     Drishti     89  Second Class

# %%
# Delete a Column

df.drop("Grade", axis=1, inplace = True)
''' axis = 1 --> column, axis = 0 --> row '''
''' inplace is used to make the changes permanently to the dataframe'''
df
# Out:
#          Name  Marks
# 0      Tanmay     95
# 1  Tannishtha    100
# 2      Jahnvi    100
# 3      Jayvee     85
# 4     Drishti     89

# %%
# Perform Basic Statistical Analysis

meandf = df["Marks"].mean()
print("Mean: ", meandf)
# Out:
# Mean:  93.8

# %%
import pandas as pd

# Create DataFrame
data = {
    "Name": ["Tira", "Vaidehi", "Meera"],
    "Marks": [85, 91, 77]
}

df = pd.DataFrame(data)

# Calculate mode
modedf = df["Marks"].mode()

print("Mode:", modedf)
# Out:
# Mode: 0    77
# 1    85
# 2    91
# Name: Marks, dtype: int64

# %%
# Aggregate Functions in Data Frames

min_value = df["Marks"].min()
max_value = df["Marks"].max()
sum_value = df["Marks"].sum()

print("Maximum of Marks: ", max_value)
print("Minimum Value of Marks: ", min_value)
print("Sum of Marks: ", sum_value)
# Out:
# Maximum of Marks:  91
# Minimum Value of Marks:  77
# Sum of Marks:  253

# %%
# Apply conditions (Filtering)
# Display Students who scored more than 90

df[df["Marks"] > 90]
# Out:
#       Name  Marks
# 1  Vaidehi     91

# %%
import pandas as pd
import numpy as np
df1=pd.DataFrame({'C1': [11,21, np.nan], 'C2': [15, np.nan, np.nan], 'C3': [10,20,30]})
df1
# Out:
#      C1    C2  C3
# 0  11.0  15.0  10
# 1  21.0   NaN  20
# 2   NaN   NaN  30

# %%
df1.isna() #Boolean Function
# Out:
#       C1     C2     C3
# 0  False  False  False
# 1  False   True  False
# 2   True   True  False

# %%
df1.notna() # Boolean function indicating non-missing values
# Out:
#       C1     C2    C3
# 0   True   True  True
# 1   True  False  True
# 2  False  False  True

# %%
df1.isna().sum() #Column-wise NaN values
# Out:
# C1    1
# C2    2
# C3    0
# dtype: int64

# %%
df1.dropna() #NaN Rows are dropped
# Out:
#      C1    C2  C3
# 0  11.0  15.0  10
